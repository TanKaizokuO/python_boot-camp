# %% [markdown]
# # Module 00: Getting Started with Python\n
# \n
# Welcome to the Free Python Course. This notebook is your first step.\n
# \n
# In this lesson you will learn:\n
# - What Python is\n
# - How to run Python code\n
# - Your first program\n
# - Basic syntax (variables, strings, numbers, conditions, loops)

# %% [markdown]
# ## What is Python?\n
# \n
# Python is a beginner-friendly programming language used for:\n
# - Web development\n
# - Data science\n
# - Automation\n
# - Machine learning\n
# - Scripting and tooling

# %%
# Your first Python program\n
print("Hello, Python!")

# %% [markdown]
# ## Variables and Data Types

# %%
name = "Learner"\n
age = 21\n
height = 5.8\n
is_learning = True\n
\n
print(name)\n
print(age)\n
print(height)\n
print(is_learning)

# %% [markdown]
# ## Basic Input and Output

# %%
# Tip: remove the comment below to try interactive input in Jupyter.\n
# user_name = input("What is your name? ")\n
# print(f"Welcome, {user_name}!")\n
\n
sample_name = "Python Student"\n
print(f"Welcome, {sample_name}!")

# %% [markdown]
# ## Conditionals

# %%
score = 72\n
\n
if score >= 90:\n
    print("Grade: A")\n
elif score >= 75:\n
    print("Grade: B")\n
else:\n
    print("Keep practicing")

# %% [markdown]
# ## Loops

# %%
for i in range(1, 6):\n
    print(f"Practice round {i}")

# %% [markdown]
# ## Next Step\n
# \n
# Great start. Continue to `1.basics.ipynb` for Module 01.
